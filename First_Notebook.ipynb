# %%
print("Aquest és el meu primer notebook")
# Out:
# Aquest és el meu primer notebook

# %% [markdown]
# Aques és el meu primer text en _cursiva_

# %% [markdown]
# # Aquest és el meu primer títol
# ## Aquest és el meu segon títol

# %%
from IPython.display import Image
Image("img/imatge.png")

# %%
from IPython.display import Image
Image("img/imatge_nbextension.png")
